# %% [markdown]
# # Sección 1
#
# Método index

# %% [markdown]
# ## Problema 1
#
# Encuentra y muestra en pantalla qué caracter ocupa la quinta posición dentro de la siguiente palabra: "orde**n**ador"

# %%
print('ordenador'[4])
# Out:
# n

# %% [markdown]
# ## Problema 2
#
# Encuentra y muestra en pantalla el índice de la primera aparición de la palabra "práctica" en la siguiente frase:
#
# "En teoría, la teoría y la práctica son los mismos. En la práctica, no lo son."

# %%
text = 'En teoría, la teoría y la práctica son los mismos. En la práctica, no lo son.'
print(text.index('práctica'))
# Out:
# 26

# %% [markdown]
# ## Problema 2
#
# Encuentra y muestra en pantalla el índice de la última aparición de la palabra "práctica" en la siguiente frase:
#
# `"En teoría, la teoría y la práctica son los mismos. En la práctica, no lo son."`

# %%
text = 'En teoría, la teoría y la práctica son los mismos. En la práctica, no lo son.'
print(text.rindex('práctica'))
# Out:
# 57

# %% [markdown]
# # Sección 2
#
# Substrings

# %% [markdown]
# ## Problema 1
#
# Extrae la primera palabra de la siguiente frase utilizando slicing, y muéstrala en pantalla:
#
# `"Controlar la complejidad es la esencia de la programación"`

# %%
text = 'Controlar la complejidad es la esencia de la programación'
print(text[:9])
# Out:
# Controlar

# %% [markdown]
# ## Problema 2
#
# Toma cada tercer caracter empezando desde el noveno hasta el final de la frase, e imprime el resultado.
#
# `"Nunca confíes en un ordenador que no puedas lanzar por una ventana"`

# %%
text = 'Nunca confíes en un ordenador que no puedas lanzar por una ventana'
print(text[8::3])
# Out:
# neeuoed eoualz rnvta

# %% [markdown]
# ## Problema 3
#
# Invierte la posición de todos los caracteres de la siguiente frase y muestra el resultado en pantalla.
#
# `Es genial trabajar con ordenadores. No discuten, lo recuerdan todo y no se beben tu cerveza"`

# %%
text = 'Es genial trabajar con ordenadores. No discuten, lo recuerdan todo y no se beben tu cerveza'
print(text[::-1])
# Out:
# azevrec ut nebeb es on y odot nadreucer ol ,netucsid oN .serodanedro noc rajabart laineg sE

# %% [markdown]
# # Sección 3
#
# Métodos de string

# %% [markdown]
# ## Problema 1
#
# Imprime el siguiente texto en mayúsculas, empleando el método específico de strings:
#
# frase = "Especialmente en las comunicaciones electrónicas, la escritura enteramente en mayúsculas equivale a gritar."

# %%
text = 'Especialmente en las comunicaciones electrónicas, la escritura enteramente en mayúsculas equivale a gritar'
print(text.upper())
# Out:
# ESPECIALMENTE EN LAS COMUNICACIONES ELECTRÓNICAS, LA ESCRITURA ENTERAMENTE EN MAYÚSCULAS EQUIVALE A GRITAR

# %% [markdown]
# ## Problema 2
#
# Une la siguiente lista en un string, separando cada elemento con un espacio. Utiliza el método apropiado de listas/strings, y muestra en pantalla el resultado.
#
# `lista_palabras = ["La","legibilidad","cuenta."]`

# %%
lista_palabras = ["La","legibilidad","cuenta."]
palabras = ' '.join(lista_palabras)
print(palabras)
# Out:
# La legibilidad cuenta.

# %% [markdown]
# ## Problema 3
#
# Reemplaza en la siguiente frase:
#
# `"Si la implementación es difícil de explicar, puede que sea una mala idea."`
#
# los siguientes pares de palabras:
#
# "difícil" --> "fácil"
#
# "mala" --> "buena"
#
# y muestra en pantalla la frase con ambas palabras modificadas.

# %%
text = 'Si la implementación es difícil de explicar, puede que sea una mala idea'
text = text.replace('difícil', 'fácil')
text = text.replace('mala', 'buena')
print(text)
# Out:
# Si la implementación es fácil de explicar, puede que sea una buena idea

# %% [markdown]
# # Sección 4
#
# Propiedades de Strings 1

# %% [markdown]
# ## Problema 1
#
# Concatena 15 veces el texto "Repetición" y muestra el resultado en pantalla.

# %%
text = 'Repetición'*15
print(text)
# Out:
# RepeticiónRepeticiónRepeticiónRepeticiónRepeticiónRepeticiónRepeticiónRepeticiónRepeticiónRepeticiónRepeticiónRepeticiónRepeticiónRepeticiónRepetición

# %% [markdown]
# ## Problema 2
#
# Verifica si la palabra "agua" no se encuentra en el siguiente haiku. Debes imprimir el booleano.
#
# Tierra mojada,
#
# mis recuerdos de viaje
#
# entre las lluvias

# %%
haiku = """
Tierra mojada,
mis recuerdos de viaje
entre las lluvias
"""

print('agua' not in haiku)
# Out:
# True

# %% [markdown]
# ## Problema 3
#
# Muestra en pantalla el largo (en números de caracteres) de la palabra `electroencefalografista`.

# %%
print(len('electroencefalografista'))
# Out:
# 23

# %% [markdown]
# # Sección 6
#
# Listas

# %% [markdown]
# ## Problema 1
#
# Crea una lista con 5 elementos, dentro de la variable mi_lista.

# %%
mi_lista = ['Uno', 1, True, 'One', 1.0]
print(mi_lista)
# Out:
# ['Uno', 1, True, 'One', 1.0]

# %% [markdown]
# ## Problema 2
#
# Agrega el elemento "motocicleta" a la siguiente lista de medios de transporte:
#
# medios_transporte = ["avión", "auto", "barco", "bicicleta"]

# %%
medios_transporte = ["avión", "auto", "barco", "bicicleta"]
medios_transporte.append('motocicleta')
print(medios_transporte)
# Out:
# ['avión', 'auto', 'barco', 'bicicleta', 'motocicleta']

# %% [markdown]
# ## Problema 3
#
# Utilizar el método pop() para quitar el tercer elemento de la siguiente lista llamada frutas, y almacénalo en una variable llamada eliminado. Utiliza métodos de listas sin alterar la línea de código ya suministrada.
#
# `frutas = ["manzana", "banana", "mango", "cereza", "sandía"]`

# %%
frutas = ["manzana", "banana", "mango", "cereza", "sandía"]
eliminado = frutas.pop(2)
